# %% [markdown]
# ### Object-Oriented Programming (OOP) in Python
#
# ##### What is OOP?
#
# **Object-Oriented Programming (OOP)** is a programming style that organizes code using **objects** and **classes**.
#
# It helps us write code that is:
# - ✅ More organized
# - ✅ Easier to reuse
# - ✅ Easier to maintain
# - ✅ More similar to real-world concepts
#
# In OOP, we create **objects** that contain:
# - **Attributes** → Data / properties of the object
# - **Methods** → Functions that describe the object's behavior
#
# ---
#
# ##### Class vs Object
#
# ##### Class
# A **class** is a blueprint or template used to create objects.
#
# Example:
# - A `Car` class is a blueprint that describes what a car has and does.
#
# ##### Object
# An **object** is an instance created from a class.
#
# Example:
# - `my_car` is an object created from the `Car` class.
#
# ---
#
# ##### Basic OOP Structure
#
# ```python
# class ClassName:
#     # attributes
#     # methods

# %%
class Employee:

    def __init__(self, name: str, age: int, gender: str, salary: float):
        self.name = name
        self.age = age
        self.gender = gender
        self.salary = salary

    def display_info(self):
        print(f"Name   : {self.name}")
        print(f"Age    : {self.age}")
        print(f"Gender : {self.gender}")
        print(f"Salary : {self.salary}")

    def calculate_total_salary(self, bonus: float) -> float:
        return self.salary + bonus


emp1 = Employee("Ahmed", 25, "Male", 25000)
emp1.display_info()
total = emp1.calculate_total_salary(5000)
print(f"Total Salary : {total}")

print("-" * 30)

emp2 = Employee("Kareem", 23, "Male", 1750)
emp2.display_info()
total = emp2.calculate_total_salary(50)
print(f"Total Salary : {total}")

print("-" * 30)

emp3 = Employee("Fatima", 28, "Female", 30000)
emp3.display_info()
total = emp3.calculate_total_salary(6000)
print(f"Total Salary : {total}")
# Out:
# Name   : Ahmed
# Age    : 25
# Gender : Male
# Salary : 25000
# Total Salary : 30000
# ------------------------------
# Name   : Kareem
# Age    : 23
# Gender : Male
# Salary : 1750
# Total Salary : 1800
# ------------------------------
# Name   : Fatima
# Age    : 28
# Gender : Female
# Salary : 30000
# Total Salary : 36000

# %% [markdown]
# ### `Class Attribute`

# %% [markdown]
# A class attribute is a variable that belongs to the class itself, not to individual objects (instances). All objects created from that class share the same value unless it is overridden in a specific object.

# %%
class student:
    total_students = 0
    college_name = ""
    def __init__(self: 'student', name: str, gender: str) -> None:
        self.name = name
        self.gender = gender
        student.total_students += 1

    def display_info(self):
        print(f"Name   : {self.name}")
        print(f"Gender : {self.gender}")
        print("-" * 30)

    def display_total_students(self):
        print(f"Total Students : {student.total_students}")

s1 = student("Ahmed", "Male")
s1.display_info()

s2 = student("Kareem", "Male")
s2.display_info()

student.college_name = "Cairo University" #! changing the class variable value using the class name

print(f"College Name : {student.college_name}")
print(f"College Name for s1: {s1.college_name}")
print(f"College Name for s2: {s2.college_name}")
print("-" * 30)

s1.college_name = "Ain Shams University" #! changing the class variable value using the object name
print(f"College Name : {student.college_name}")
print(f"College Name for s1: {s1.college_name}")
print(f"College Name for s2: {s2.college_name}")

s1.display_total_students()
# Out:
# Name   : Ahmed
# Gender : Male
# ------------------------------
# Name   : Kareem
# Gender : Male
# ------------------------------
# College Name : Cairo University
# College Name for s1: Cairo University
# College Name for s2: Cairo University
# ------------------------------
# College Name : Cairo University
# College Name for s1: Ain Shams University
# College Name for s2: Cairo University
# Total Students : 2

# %% [markdown]
# ### `Class Method`

# %% [markdown]
# A class method is a method that belongs to the class, not to a specific object (instance). It uses the @classmethod decorator and receives the class (cls) as its first parameter instead of an instance (self).

# %%
class Vet:
    num_of_animals = 0

    @classmethod
    def display_num_of_animals(cls):
        print(f"Total Animals : {cls.num_of_animals}")

    def __init__(self, name: str, animal_type: str):
        self.name = name
        self.animal_type = animal_type
        Vet.num_of_animals += 1

    def display_info(self):
        print(f"Name   : {self.name}")
        print(f"Type   : {self.animal_type}")
        print("-" * 30)

animal1 = Vet("Dog", "Mammal")
animal1.display_info()

animal2 = Vet("Cat", "Mammal")
animal2.display_info()

Vet.display_num_of_animals()
# Out:
# Name   : Dog
# Type   : Mammal
# ------------------------------
# Name   : Cat
# Type   : Mammal
# ------------------------------
# Total Animals : 2

# %% [markdown]
# ### `Static Method`

# %% [markdown]
# A static method is a method that belongs to a class but does not use either the instance (self) or the class (cls). It is defined using the @staticmethod decorator.

# %%
class Demo:
    class_variable = "Python"

    def instance_method(self):
        print("Instance Method")
        print(self.class_variable)

    @classmethod
    def class_method(cls):
        print("Class Method")
        print(cls.class_variable)

    @staticmethod
    def static_method():
        print("Static Method")

d = Demo()

d.instance_method()
Demo.class_method()
Demo.static_method()
# Out:
# Instance Method
# Python
# Class Method
# Python
# Static Method

# %%
class Compney:

    total_companies = 0
    @classmethod
    def display_total_companies(cls):
        print(f"Total Companies : {cls.total_companies}")
        print("-" * 30)

    def __init__(self, name: str, employees: list):
        self.name = name
        self.employees = employees
        Compney.total_companies += 1

    def display_info(self):
        print(f"Company Name : {self.name}")
        print("Employees:")
        for employee in self.employees:
            print(f" - {employee}")
        print("-" * 30)

    @staticmethod
    def instruction():
        print("This is a static method that provides instructions for the company.")
        print("You can use this method to get guidance on how to manage other companies effectively.")
        print("-" * 30)

c1 = Compney("TechCorp", ["Ahmed", "Kareem", "Fatima"])
c1.display_info()

c2 = Compney("InnovateX", ["Ali", "Sara"])
c2.display_info()

Compney.display_total_companies()
Compney.instruction()
# Out:
# Company Name : TechCorp
# Employees:
#  - Ahmed
#  - Kareem
#  - Fatima
# ------------------------------
# Company Name : InnovateX
# Employees:
#  - Ali
#  - Sara
# ------------------------------
# Total Companies : 2
# ------------------------------
# This is a static method that provides instructions for the company.
# You can use this method to get guidance on how to manage other companies effectively.
# ------------------------------

# %% [markdown]
# ### `Inheritance`

# %% [markdown]
# Inheritance is one of the four main principles of Object-Oriented Programming (OOP). It allows a new class (child/derived class) to inherit the attributes and methods of an existing class (parent/base class).

# %%
class Person:
    def __init__(self, name:str, age:int, gender:str)->None:
        self.name = name
        self.age = age
        self.gender = gender

    def printAll(self)->None:
        print(f"Name: {self.name}")
        print(f'Age: {self.age}')
        print(f"Gender: {self.gender}")

class Employee(Person):

    def __init__(self, name:str, age:int, gender:str, salary:float)->None:
        Person.__init__(self, name, age, gender)
        self.salary = salary       

    def printAll(self)->None:
        super().printAll()
        print(f"Salary: {self.salary}")

Emp1 = Employee("Ali", 15, "Male", 50000)
Emp1.printAll()
# Out:
# Name: Ali
# Age: 15
# Gender: Male
# Salary: 50000

# %%
class Manager:
    def __init__(self, name:str, id:int, location:str)->None:
        self.name = name
        self.id = id
        self.location = location

    def printAll(self)->None:
        print(f"Name: {self.name}")
        print(f"ID: {self.id}")
        print(f"Location: {self.location}")

# %%
class CEO(Employee, Manager):
    def __init__(self, name: str, id: int, location: str,
                 age: int, gender: str, salary: float) -> None:

        Employee.__init__(self, name, age, gender, salary)
        Manager.__init__(self, name, id, location)

    def printAll(self) -> None:
        Employee.printAll(self)
        print(f"ID: {self.id}")
        print(f"Location: {self.location}")

# Test CEO
ceo1 = CEO("Khaled", 1, "Egypt", 30, "Male", 50000.99)
ceo1.printAll()
# Out:
# Name: Khaled
# Age: 30
# Gender: Male
# Salary: 50000.99
# ID: 1
# Location: Egypt

# %%
print(CEO.__mro__)
# Out:
# (<class '__main__.CEO'>, <class '__main__.Employee'>, <class '__main__.Person'>, <class '__main__.Manager'>, <class 'object'>)

# %% [markdown]
# ### `Polymorphism`

# %% [markdown]
# Polymorphism means "many forms." In OOP, it allows the same method name or interface to behave differently depending on the object that calls it.
#
# In simple words:
# One method name → Different behaviors

# %% [markdown]
# - **Method Overriding**:
# Method overriding occurs when a child class provides its own implementation of a method that already exists in the parent class.
# - **Method Overloading**
# Method overloading means having multiple methods with the same name but different parameters.
# In languages like Java or C++ .
# Python does not support traditional method overloading.
# If you define two methods with the same name, the second one replaces the first.

# %% [markdown]
# - *Method Overriding*

# %%
class Shape:
    def area(self):
        return 0

class Rectangle(Shape):
    def __init__(self, width:float, height:float)->None:
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

r1 = Rectangle(50, 100)
r1.area()
# Out:
# 5000

# %%
class Animal:
    def sound(self):
        print("This is the original sound")
        print('-' * 30)

class Cat(Animal):
    def sound(self):
        print("Maw")
        print('-' * 30)


class Dog(Animal):
    def sound(self):
        super().sound()
        print("Waff")
        print('-' * 30)


c1 = Cat()
c1.sound()

d1 = Dog()
d1.sound()
# Out:
# Maw
# ------------------------------
# This is the original sound
# ------------------------------
# Waff
# ------------------------------

# %% [markdown]
# - *method overloading*

# %%
class Calculate:
    @staticmethod
    def getsum(*nums):
        result = 0
        for i in nums:
            result+=i
        return result

c1 = Calculate()
print(c1.getsum(1,2,3))
print(c1.getsum(4,5))
print(c1.getsum(10,500,60))
# Out:
# 6
# 9
# 570

# %% [markdown]
# ### `Encapsulation`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Public vs Protected vs Private in Python
#
# | Access Level | Syntax | Accessible Outside Class? | Accessible in Child Class? | Purpose |
# |--------------|--------|---------------------------|----------------------------|---------|
# | **Public** | `name` | Yes | Yes | Normal attributes and methods |
# | **Protected** | `_name` | Yes (but discouraged) | Yes | Internal use within the class and subclasses |
# | **Private** | `__name` | No (not directly) | No (not directly) | Hide implementation details using name mangling |
#
# ##### Summary
#
# ##### Public (`name`)
# - Accessible from anywhere.
# - Default access level in Python.
# - Used for attributes and methods that are part of the class's public interface.
#
# ##### Protected (`_name`)
# - Intended for internal use within the class and its subclasses.
# - Still accessible from outside the class, but by convention should not be accessed directly.
# - Python does **not** enforce protection.
#
# ##### Private (`__name`)
# - Intended to hide implementation details.
# - Uses **name mangling** (`__name` → `_ClassName__name`) to reduce accidental access.
# - Should be accessed through methods or properties (`@property`) instead of directly.
#
# > **Note:** Python does not have true access modifiers like Java or C++. Public, protected, and private are implemented using naming conventions and name mangling rather than strict access restrictions.

# %%
class Employee:
    def __init__(self, name:str , salary:float)->None:
        self.name = name
        self.salary = salary

    def changeManagerSalary(self,obj, NewSalary:float): #* Test modify manager salary
        obj.salary = NewSalary

class Manager:
    def __init__(self, name:str, salary:float):
        self.name = name
        self._salary = salary   #! Protected

    def displayData(self):
        print(f"Name: {self.name}")
        print(f"Salary: {self._salary}")
        print('-' * 30)

class CEO(Manager):
    def __init__(self, name:str, salary:float):
            super().__init__(name, salary)
            self.__salary = salary   #! Private

    def setCEO_Salary(self, NewSalary:float):
        self.__salary = NewSalary

    def getCEO_Salary(self):
         return self.__salary

    def setManagerSalary(self, obj, NewSalary:float):
         obj._salary = NewSalary



emp1 = Employee("Ahmed", 2000)
mng1 = Manager("Mohammed", 3000)

emp1.changeManagerSalary(mng1, 5000) #! The Employee can not modify manager salary

mng1.displayData()

ceo1 = CEO("Ali", 50000)
ceo1.setManagerSalary(mng1, 1000)

mng1.displayData()

ceo = CEO("Khaled", 50000)

ceo.displayData()                 # Protected salary
print(ceo.getCEO_Salary())         # Private salary
ceo.setCEO_Salary(70000)

ceo.displayData()
print(ceo.getCEO_Salary())
# Out:
# Name: Mohammed
# Salary: 3000
# ------------------------------
# Name: Mohammed
# Salary: 1000
# ------------------------------
# Name: Khaled
# Salary: 50000
# ------------------------------
# 50000
# Name: Khaled
# Salary: 50000
# ------------------------------
# 70000
